# %%
import pandas as pd

# %%
# Testing to make sure pandas is working correctly
my_list = [2, 4, 6, 8]

# %%
my_series = pd.Series(my_list)

# %%
my_series.sum()
# Out:
# 20

# %%
my_series.max()
# Out:
# 8

# %%
fe_list = pd.read_csv("../data/FE08_03_20.csv")

# %%
fe_list.head()
# Out:
#    Unique ID         Subject's name Subject's age Subject's gender  \
# 0    25746.0        Samuel H. Knapp            17             Male
# 1    25747.0         Mark A. Horton            21             Male
# 2    25748.0  Phillip A. Blurbridge            19             Male
# 3    25749.0             Mark Ortiz            23             Male
# 4        2.0          Lester Miller            53             Male
#
#             Subject's race Subject's race with imputations  \
# 0  European-American/White         European-American/White
# 1   African-American/Black          African-American/Black
# 2   African-American/Black          African-American/Black
# 3          Hispanic/Latino                 Hispanic/Latino
# 4         Race unspecified          African-American/Black
#
#   Imputation probability URL of image of deceased  \
# 0            Not imputed                      NaN
# 1            Not imputed                      NaN
# ...

# %%
fe_list.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28525 entries, 0 to 28524
# Data columns (total 29 columns):
#  #   Column                                                          Non-Null Count  Dtype
# ---  ------                                                          --------------  -----
#  0   Unique ID                                                       28524 non-null  float64
#  1   Subject's name                                                  28525 non-null  object
#  2   Subject's age                                                   27518 non-null  object
#  3   Subject's gender                                                28426 non-null  object
#  4   Subject's race                                                  28524 non-null  object
#  5   Subject's race with imputations                                 28393 non-null  object
#  6   Imputation probability                                          28385 non-null  object
# ...

# %%
fe_list.fillna("")
# Out:
#       Unique ID                              Subject's name Subject's age  \
# 0         25746                             Samuel H. Knapp            17
# 1         25747                              Mark A. Horton            21
# 2         25748                       Phillip A. Blurbridge            19
# 3         25749                                  Mark Ortiz            23
# 4             2                               Lester Miller            53
# ...         ...                                         ...           ...
# 28520     28521                               Bismark Asare            40
# 28521     28522                     Name withheld by police
# 28522     28523                           Adrean Stephenson            63
# 28523     28524                  Christopher Kimmons Craven            38
# 28524            This is a spacer for Fatal Encounters use.
#
#       Subject's gender           Subject's race  \
# 0                 Male  European-American/White
# ...

# %%
fe_list["Agency responsible for death"].value_counts()
# Out:
# Los Angeles Police Department                                                                                         469
# Chicago Police Department                                                                                             426
# Los Angeles County Sheriff's Department                                                                               348
# City of New York Police Department                                                                                    327
# Houston Police Department                                                                                             311
#                                                                                                                      ...
# Kansas City (MO) Police Department                                                                                      1
# Lincoln Police Department, Placer County Sheriff's Office                                                               1
# ...

# %%
#Top 50 in police killings by state. MO has 871 police killings since 200, and KS has 391 police killings
fe_list["Location of death (state)"].value_counts()
# Out:
# CA    4571
# TX    2520
# FL    1728
# GA    1071
# IL    1045
# OH     937
# PA     924
# MO     880
# MI     841
# AZ     827
# OK     658
# NY     647
# AL     633
# CO     623
# WA     616
# TN     613
# LA     596
# NC     596
# VA     589
# SC     541
# IN     532
# NJ     514
# MD     508
# WI     432
# MS     409
# KS     394
# NM     384
# KY     383
# NV     375
# AR     356
# MN     317
# OR     317
# IA     262
# UT     235
# NE     196
# MA     189
# WV     172
# ID     139
# CT     135
# AK     118
# HI     106
# MT      96
# ME      96
# DC      81
# DE      59
# WY      56
# SD      55
# NH      52
# VT      39
# ND      35
# RI      26
# Name: Location of death (state), dtype: int64

# %%
# Worst years for police killngs.
fe_list["Date (Year)"].sort_values(ascending = False).value_counts()
# Out:
# 2018    1852
# 2019    1811
# 2013    1784
# 2017    1767
# 2014    1717
# 2015    1608
# 2016    1598
# 2012    1485
# 2011    1408
# 2010    1293
# 2006    1269
# 2009    1257
# 2007    1255
# 2008    1210
# 2020    1194
# 2005    1170
# 2003    1052
# 2004    1037
# 2002     986
# 2001     923
# 2000     848
# 2100       1
# Name: Date (Year), dtype: int64

# %%
# Creat a mutated list where only Kansas cases are represented
my_state = 'KS'

# %%
ks_fatalencounters = fe_list[fe_list["Location of death (state)"] == my_state]
ks_fatalencounters
# Out:
#        Unique ID            Subject's name Subject's age Subject's gender  \
# 42          21.0         Robert H. Golding            43             Male
# 92          54.0            Toshua Dearman            15           Female
# 119         77.0         Ilesh Ashok Abdir            27             Male
# 145         95.0  Vincent "Vinny" A. Smith            16             Male
# 391        283.0        Pappy Lupe Chapman            27             Male
# ...          ...                       ...           ...              ...
# 28003    27965.0    Phillip Michael Carney            38             Male
# 28062    28020.0         Damien St. Julien            39             Male
# 28280    28255.0           Nicholas Hirsch            31             Male
# 28313    28293.0      Ricardo J. Rodriguez            20             Male
# 28456    28446.0             Kevin Trahern            49             Male
#
#                 Subject's race Subject's race with imputations  \
# ...

# %%
ks_fatalencounters.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 394 entries, 42 to 28456
# Data columns (total 29 columns):
#  #   Column                                                          Non-Null Count  Dtype
# ---  ------                                                          --------------  -----
#  0   Unique ID                                                       394 non-null    float64
#  1   Subject's name                                                  394 non-null    object
#  2   Subject's age                                                   377 non-null    object
#  3   Subject's gender                                                394 non-null    object
#  4   Subject's race                                                  394 non-null    object
#  5   Subject's race with imputations                                 392 non-null    object
#  6   Imputation probability                                          392 non-null    object
# ...

# %%
ks_fatalencounters.fillna("")
# Out:
#        Unique ID            Subject's name Subject's age Subject's gender  \
# 42          21.0         Robert H. Golding            43             Male
# 92          54.0            Toshua Dearman            15           Female
# 119         77.0         Ilesh Ashok Abdir            27             Male
# 145         95.0  Vincent "Vinny" A. Smith            16             Male
# 391        283.0        Pappy Lupe Chapman            27             Male
# ...          ...                       ...           ...              ...
# 28003    27965.0    Phillip Michael Carney            38             Male
# 28062    28020.0         Damien St. Julien            39             Male
# 28280    28255.0           Nicholas Hirsch            31             Male
# 28313    28293.0      Ricardo J. Rodriguez            20             Male
# 28456    28446.0             Kevin Trahern            49             Male
#
#                 Subject's race Subject's race with imputations  \
# ...

# %%
#Export dataset to csv with code below
#ks_fatalencounters.to_csv('../output/KS_FatalEncounters08032020.csv', index=False)

# %%
# Creat a mutated list where only Missouri cases are represented
mo_state = 'MO'

# %%
mo_fatalencounters = fe_list[fe_list["Location of death (state)"] == mo_state]
mo_fatalencounters
# Out:
#        Unique ID            Subject's name Subject's age Subject's gender  \
# 54          28.0   Name withheld by police            34             Male
# 66          35.0             Robert Corgan            18             Male
# 113         73.0         Sandra L. Roberts            41           Female
# 128         86.0               Jovan Young            23             Male
# 139         90.0         Arthur G. Dobbins            19             Male
# ...          ...                       ...           ...              ...
# 28372    28367.0   Name withheld by police           NaN             Male
# 28388    28384.0  William Wade Burgess III            27             Male
# 28398    28392.0   Name withheld by police           NaN           Female
# 28435    28483.0   Name withheld by police           NaN             Male
# 28497    28500.0   Name withheld by police            48             Male
#
#                Subject's race Subject's race with imputations  \
# ...

# %%
mo_fatalencounters.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 880 entries, 54 to 28497
# Data columns (total 29 columns):
#  #   Column                                                          Non-Null Count  Dtype
# ---  ------                                                          --------------  -----
#  0   Unique ID                                                       880 non-null    float64
#  1   Subject's name                                                  880 non-null    object
#  2   Subject's age                                                   851 non-null    object
#  3   Subject's gender                                                880 non-null    object
#  4   Subject's race                                                  880 non-null    object
#  5   Subject's race with imputations                                 877 non-null    object
#  6   Imputation probability                                          877 non-null    object
# ...

# %%
mo_fatalencounters.fillna("")
# Out:
#        Unique ID            Subject's name Subject's age Subject's gender  \
# 54          28.0   Name withheld by police            34             Male
# 66          35.0             Robert Corgan            18             Male
# 113         73.0         Sandra L. Roberts            41           Female
# 128         86.0               Jovan Young            23             Male
# 139         90.0         Arthur G. Dobbins            19             Male
# ...          ...                       ...           ...              ...
# 28372    28367.0   Name withheld by police                           Male
# 28388    28384.0  William Wade Burgess III            27             Male
# 28398    28392.0   Name withheld by police                         Female
# 28435    28483.0   Name withheld by police                           Male
# 28497    28500.0   Name withheld by police            48             Male
#
#                Subject's race Subject's race with imputations  \
# ...

# %%
#Export dataset to csv with code below
mo_fatalencounters.to_csv('../output/MO_FatalEncounters08032020.csv', index=False)

# %% [markdown]
# Next step will be to import new KS and MO datasets and merge both sets into a new sheet based off a similar characteristic.
